# %% [markdown]
# ## Primera clase pcp

# %% [markdown]
# 1.Muestra que version de pip tiene ?

# %%
# !pip --version
# Out:
# pip 23.2.1 from C:\Program Files\Python311\Lib\site-packages\pip (python 3.11)

# %%
import platform as pt

# %% [markdown]
# ## System Specs

# %%
pt.uname()
# Out:
# uname_result(system='Windows', node='MSI', release='10', version='10.0.22621', machine='AMD64')

# %%
pt.platform()
# Out:
# 'Windows-10-10.0.22621-SP0'

# %% [markdown]
# ## Cores?

# %%
import os

# %%
os.cpu_count()
# Out:
# 12

# %% [markdown]
# # 3/Oct/2023
# ### Threads.

# %% [markdown]
# ### Import libs,mange threads

# %%
import threading as th

# %%
th.active_count()
# Out:
# 6

# %%
th.current_thread().getName().

# %%
th.enumerate()
# Out:
# [<_MainThread(MainThread, started 17720)>,
#  <Thread(IOPub, started daemon 10020)>,
#  <Heartbeat(Heartbeat, started daemon 9160)>,
#  <ControlThread(Control, started daemon 11260)>,
#  <HistorySavingThread(IPythonHistorySavingThread, started 12072)>,
#  <ParentPollerWindows(Thread-4, started daemon 19660)>]

# %% [markdown]
# # who is the parent ?

# %%
import os

# %%
os.getpid()
# Out:
# 18780

# %%
from IPython import display as dp

# %% [markdown]
# The parent is?

# %%
dp.Image('CapturaPCD.png')

# %% [markdown]
# # threads VS process

# %% [markdown]
# ## threads ex.

# %%
def do_nothing():
    while True:
        pass

# %%
for i in range(20):
    th.Thread(target=do_nothing).start()

th.enumerate()
# Out:
# [<_MainThread(MainThread, started 16256)>,
#  <Thread(IOPub, started daemon 4300)>,
#  <Heartbeat(Heartbeat, started daemon 14604)>,
#  <ControlThread(Control, started daemon 17548)>,
#  <HistorySavingThread(IPythonHistorySavingThread, started 11744)>,
#  <ParentPollerWindows(Thread-4, started daemon 848)>,
#  <GarbageCollectorThread(Thread-5, started daemon 9812)>,
#  <Thread(Thread-7 (do_nothing), started 12912)>,
#  <Thread(Thread-8 (do_nothing), started 7048)>,
#  <Thread(Thread-9 (do_nothing), started 14572)>,
#  <Thread(Thread-10 (do_nothing), started 16932)>,
#  <Thread(Thread-11 (do_nothing), started 2788)>,
#  <Thread(Thread-12 (do_nothing), started 6416)>,
#  <Thread(Thread-13 (do_nothing), started 16260)>,
#  <Thread(Thread-14 (do_nothing), started 7068)>,
#  <Thread(Thread-15 (do_nothing), started 1796)>,
#  <Thread(Thread-16 (do_nothing), started 15816)>,
#  <Thread(Thread-17 (do_nothing), started 16092)>,
#  <Thread(Thread-18 (do_nothing), started 13084)>,
#  <Thread(Thread-19 (do_nothing), started 8716)>,
#  <Thread(Thread-20 (do_nothing), started 6744)>,
#  <Thread(Thread-21 (do_nothing), started 16008)>,
#  <Thread(Thread-22 (do_nothing), started 8896)>,
#  <Thread(Thread-23 (do_nothing), started 3224)>,
#  <Thread(Thread-24 (do_nothing), started 6116)>,
#  <Thread(Thread-25 (do_nothing), started 14916)>,
#  <Thread(Thread-26 (do_nothing), started 18984)>]

# %% [markdown]
# ## Process Ex

# %%
for i in range(20):
    mp.Process(target= do_nothing()).start

# %%
mp.enumerate()

# %% [markdown]
# ### Cuantos hilos puedo instanciar?

# %% [markdown]
# ### Import libs,mange process(cores)

# %%
import multiprocessing as mp # Manages cores

# %%
mp.cpu_count()
# Out:
# 12

# %%
mp.current_process()
# Out:
# <_MainProcess name='MainProcess' parent=None started>

# %% [markdown]
# ### Cual es mi interprete de Python ?

# %%
! python3 --version
# Out:
# Python 3.11.5

# %%
import platform as pt

# %%
pt.python_implementation()
# Out:
# 'CPython'

# %%
pt.python_compiler()
# Out:
# 'MSC v.1936 64 bit (AMD64)'

# %%
[[1,2,3,4],[4,6,7]]
# Out:
# ([1, 2, 3, 4], [4, 6, 7])

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.ipynb_checkpoints/
# 	Clase5Ocutubre_Miguel_Marchal_mallavibarrena.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git init
# Out:
# Reinitialized existing Git repository in C:/Users/mmarc/PCD_2023/.git/

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   .ipynb_checkpoints/Clase5Ocutubre_Miguel_Marchal_mallavibarrena-checkpoint.ipynb
# 	new file:   Clase5Ocutubre_Miguel_Marchal_mallavibarrena.ipynb

# %%
# !git commit -m"clse 5 oct 2023"
# Out:
# [main 72bc254] clse 5 oct 2023
#  2 files changed, 1315 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Clase5Ocutubre_Miguel_Marchal_mallavibarrena-checkpoint.ipynb
#  create mode 100644 Clase5Ocutubre_Miguel_Marchal_mallavibarrena.ipynb

# %%
# !git push
# Out:
# To https://github.com/cuatrobrazos1/PCD_2023.git
#    86b990f..72bc254  main -> main

# %%
# !git push -f
# Out:
# Everything up-to-date
